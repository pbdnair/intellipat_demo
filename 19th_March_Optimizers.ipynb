# %% [markdown]
# <a href="https://colab.research.google.com/github/pbdnair/intellipat_demo/blob/main/19th_March_Optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Plant Pathology 2020
# kaggle competitions download -c plant-pathology-2020-fgvc7

# %%
! mkdir -p /root/.kaggle 
! mv kaggle.json /root/.kaggle

# %%
! kaggle competitions download -c plant-pathology-2020-fgvc7
# Out:
# ...
# 100% 776M/779M [00:04<00:00, 203MB/s]
# 100% 779M/779M [00:04<00:00, 203MB/s]

# %%
# If it downloads singles images, please reinstall kaggle and try again
# ! yes | pip -q uninstall kaggle 
# ! pip -q install --upgrade kaggle

# %% [markdown]
# ![Screenshot 2022-03-19 at 8.03.58 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![2AFF8C45-56F4-4204-9FF5-EEE159EF1AD4_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![30A364CE-4540-4744-AD87-B29025F89FD8_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![734808F7-72B0-44B7-847F-3036F01FF86A_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![4C408D48-A070-4941-AFFC-762D9A77C809_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![85020691-D7FD-4B1A-A543-A4C9F7FE3D6E_1_201_a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![E977018E-64C6-4807-A2D3-EF9B7440F66F_1_201_a.jpeg](data:image/jpeg;base64,...)
